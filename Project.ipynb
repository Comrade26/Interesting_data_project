# %%
from forex_python.converter import CurrencyRates
import pandas as pd
import datetime as datetime
import re

# %%
df = pd.read_csv("income_by_sex.csv")

df

# %%
all_name = list(df.Geography)
continent = ["Asia", "Europe", "Africa", "America", "World"]
economic_groups = ['APEC','APEC','ASEAN','ASEAN',
'BRIC','BRIC','Developed Countries','Developed Countries','EMEA','EMEA','Emerging and Developing Countries','Emerging and Developing Countries','EU with United Kingdom','EU with United Kingdom','EU','EU','EuroZone','EuroZone','G7','G7''G8','G8','G20','G20','GCC','GCC','Mercosur','Mercosur','MINT','MINT','NAFTA','NAFTA','OECD','OECD']
country_name = []

for i in all_name:
    match = re.search("|".join(continent), i) or re.search("|".join(economic_groups), i)
    if match:
        pass
    else:   country_name.append(i)
country_name
# Out:
# ['Azerbaijan',
#  'Azerbaijan',
#  'Bangladesh',
#  'Bangladesh',
#  'Cambodia',
#  'Cambodia',
#  'China',
#  'China',
#  'Hong Kong, China',
#  'Hong Kong, China',
#  'India',
#  'India',
#  'Indonesia',
#  'Indonesia',
#  'Japan',
#  'Japan',
#  'Kazakhstan',
#  'Kazakhstan',
#  'Laos',
#  'Laos',
#  'Malaysia',
#  'Malaysia',
#  'Myanmar',
#  'Myanmar',
#  'Pakistan',
#  'Pakistan',
#  'Philippines',
#  'Philippines',
#  'Singapore',
#  'Singapore',
#  'South Korea',
#  'South Korea',
#  'Sri Lanka',
#  'Sri Lanka',
#  'Taiwan',
#  'Taiwan',
#  'Thailand',
#  'Thailand',
#  'Turkmenistan',
#  'Turkmenistan',
#  'Uzbekistan',
#  'Uzbekistan',
#  'Vietnam',
#  'Vietnam',
#  'Australasia',
#  'Australasia',
#  'Australia',
#  'Australia',
#  'New Zealand',
#  'New Zealand',
#  'Belarus',
#  'Belarus',
#  'Bosnia and Herzegovina',
#  'Bosnia and Herzegovina',
#  'Bulgaria',
#  'Bulgaria',
#  'Croatia',
#  'Croatia',
#  'Czech Republic',
#  'Czech Republic',
#  'Estonia',
# ...

# %%
name = ["asia pacific"]
no_name = ["asia"]

for i in name:
    match = re.search("|".join(no_name), i)
    print(match)
# Out:
# <re.Match object; span=(0, 4), match='asia'>
